# %%
pip install pandas sqlalchemy pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.1 MB 495.5 kB/s eta 0:00:05
#    -- ------------------------------------- 0.1/2.1 MB 939.4 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/2.1 MB 1.4 MB/s eta 0:00:02
#    -------- ------------------------------- 0.5/2.1 MB 2.3 MB/s eta 0:00:01
#    ------------ --------------------------- 0.6/2.1 MB 2.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.1 MB 4.1 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.1 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 5.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/297.0 kB ? eta -:--:--
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Load CSV
df = pd.read_csv("C:\\Users\\rahul\\OneDrive\\SQL\\Flight Dashboard using Python and sql\\flights_cleaned - flights_cleaned.csv")

# Connect to MySQL
engine = create_engine("mysql+pymysql://root:1234@localhost/dash")

# Push DataFrame to MySQL (automatic column mapping)
df.to_sql('flight', con=engine, if_exists='append', index=False)
# Out:
# 10683
