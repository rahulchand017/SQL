# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    --------- ------------------------------ 10.2/45.0 kB ? eta -:--:--
#    --------- ------------------------------ 10.2/45.0 kB ? eta -:--:--
#    --------------------------- ------------ 30.7/45.0 kB 186.2 kB/s eta 0:00:01
#    ------------------------------------ --- 41.0/45.0 kB 245.8 kB/s eta 0:00:01
#    ---------------------------------------- 45.0/45.0 kB 201.9 kB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\rahul\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pymysql
import pandas as pd
mydb = pymysql.connect(
    host="127.0.0.1",
    user="root",
    password="1234"
)

# %%
mycursor = mydb.cursor()
mycursor.execute("SHOW DATABASES")
db = mycursor.fetchall()
for i in db:
    print(i[0])
# Out:
# campusx
# course
# demo
# flights
# flipkart
# imdb
# information_schema
# mysql
# order_project
# performance_schema
# practice
# sales
# sql_cx
# subquery
# sys
# zomato

# %%
# create a database on the db server 
mycursor.execute("CREATE DATABASE indigo")
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[10], line 2
#       1 # create a database on the db server
# ----> 2 mycursor.execute("CREATE DATABASE indigo")
#       3 mydb.commit()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# ProgrammingError: (1007, "Can't create database 'indigo'; database exists")

# %%
import pymysql
import pandas as pd
mydb = pymysql.connect(
    host="127.0.0.1",
    user="root",
    password="1234",
    database = 'indigo'
)

# %%
mycursor = mydb.cursor()

# %%
# Create a table
mycursor.execute("""
                 create table airport(
                     airport_id INTEGER PRIMARY KEY,
                     code VARCHAR(10)NOT NULL,
                     city VARCHAR(50) NOT NULL,
                     name VARCHAR(255) NOT NULL
                     )""")
mydb.commit()

# %%
# insert data to the table
mycursor.execute("""
                 INSERT INTO airport VALUES
                 (1,'DEL', 'New DELHI', 'IGIA'),
                 (2,'CCU','Kolkata','NSCB')
                 """)
mydb.commit()

# %%
# search
mycursor.execute("SElect * from airport where airport_id>1")
data = mycursor.fetchall()
print(data)
for i in data:
    print(i[3])
# Out:
# ((2, 'CCU', 'Kolkata', 'NSCB'),)
# NSCB

# %%
# update
mycursor.execute('''
                 UPDATE airport 
                 set city = 'Bombay'
                 WHERE airport_id = 2''')
mydb.commit()

# %%
mycursor.execute("SElect * from airport")
data = mycursor.fetchall()
print(data)
# Out:
# ((1, 'DEL', 'New DELHI', 'IGIA'), (2, 'CCU', 'Bombay', 'NSCB'))

# %%
# DELETE
mycursor.execute("DELETE from airport where airport_id = 2")
mydb.commit()

# %%
mycursor.execute("SElect * from airport")
data = mycursor.fetchall()
print(data)
# Out:
# ((1, 'DEL', 'New DELHI', 'IGIA'),)

# %% [markdown]
# ##### Code to import database using sql
#
# ![image.png](attachment:image.png)
